# %% [markdown]
# # Creating ISOCRONES
# based on tutorial :
# > https://towardsdatascience.com/how-to-calculate-travel-time-for-any-location-in-the-world-56ce639511f

# %%
import geopandas as gpd
from shapely.geometry import Point, LineString, Polygon

import networkx as nx
import osmnx as ox

import matplotlib.pyplot as plt
from descartes import PolygonPatch

#from IPython.display import IFrame
#ox.config(log_console=True, use_cache=True)

# %%
#modules needed for connecting to PostGIS
from sqlalchemy.engine.url import URL
from sqlalchemy import create_engine #needs to have psycopg2 in the environment but no need to import it
from geoalchemy2 import WKTElement, Geometry #to modify Shapely geometries into WKT before uploading to DB

# %%
# DB parameters
HOST = 'localhost'
DB = 'sdb_course'
USER = 'postgres'
PORT = 5433
PWD = 'Dedalo1.'

# Database info
db_url = URL(drivername='postgresql+psycopg2', 
             host=HOST, 
             database=DB,
             username=USER,
             port=PORT,
             password=PWD)
# Create engine
engine = create_engine(db_url)
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5433/sdb_course)

# %%
#importing the Network sevgments
sqlquery = "SELECT * FROM riyadh.campuses_new;"

#note: no CRS given because the data is already projcted in the correct CRS (20438)
camp_2 = gpd.read_postgis(sqlquery, engine, geom_col='geom', crs=None)
#creating a spatial index
camp_2.sindex
camp_2.head(2)
# Out:
#    id                                               geom category  \
# 0   1  MULTIPOLYGON (((679977.382 2734669.908, 680392...        E
# 1   2  MULTIPOLYGON (((674069.638 2747370.597, 672094...        E
#
#       cat_name name_alias
# 0  Educational       None
# 1  Educational       None

# %%
focus_camps = camp_2[camp_2.name_alias.notnull()]
focus_camps
# Out:
#       id                                               geom category  \
# 225  226  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 289  283  MULTIPOLYGON (((663016.043 2728333.928, 662887...   SCLSUP
# 296  290  MULTIPOLYGON (((671687.142 2728023.176, 671877...     SCRT
# 313  314  MULTIPOLYGON (((670674.677 2745810.355, 670743...        E
#
#                                       cat_name                 name_alias
# 225                Residential Gated Community            Telal Al-Riyadh
# 289  Self-Contained Large-Scale Urban Projects  Diplomatic Quarter Riyadh
# 296                                   Security       Royal Guard Barracks
# 313                                Educational         Al-Imam University

# %%
focus_camps = focus_camps.join(entrances.set_index("campus_id"), on ="id")
focus_camps.head()
# Out:
#       id                                               geom category  \
# 225  226  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 225  226  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 225  226  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 225  226  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 225  226  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
#
#                         cat_name       name_alias   id_0     northing  \
# 225  Residential Gated Community  Telal Al-Riyadh  27592  2744105.822
# 225  Residential Gated Community  Telal Al-Riyadh  27756  2744175.309
# 225  Residential Gated Community  Telal Al-Riyadh  27757  2744299.502
# 225  Residential Gated Community  Telal Al-Riyadh  27758  2744372.615
# 225  Residential Gated Community  Telal Al-Riyadh  42899  2743462.888
#
#          easting  longitude   latitude
# 225  662480.3411  46.607466  24.803135
# 225  662624.1597  46.608896  24.803748
# 225  662881.2041  46.611453  24.804841
# 225  663032.5274  46.612958  24.805485
# 225  663540.7913  46.617879  24.797218

# %%
focus_camps.set_index(["id", "id_0"],inplace=True)

# %%
focus_camps.loc[226]
# Out:
#                                                      geom category  \
# id_0
# 27592   MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 27756   MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 27757   MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 27758   MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 42899   MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 53332   MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 196847  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 196852  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
# 196860  MULTIPOLYGON (((662279.772 2744025.574, 663244...        R
#
#                            cat_name       name_alias     northing  \
# id_0
# 27592   Residential Gated Community  Telal Al-Riyadh  2744105.822
# 27756   Residential Gated Community  Telal Al-Riyadh  2744175.309
# 27757   Residential Gated Community  Telal Al-Riyadh  2744299.502
# 27758   Residential Gated Community  Telal Al-Riyadh  2744372.615
# 42899   Residential Gated Community  Telal Al-Riyadh  2743462.888
# 53332   Residential Gated Community  Telal Al-Riyadh  2744031.632
# 196847  Residential Gated Community  Telal Al-Riyadh  2743360.894
# 196852  Residential Gated Community  Telal Al-Riyadh  2743472.912
# 196860  Residential Gated Community  Telal Al-Riyadh  2744239.592
#
#             easting  longitude   latitude
# id_0
# 27592   662480.3411  46.607466  24.803135
# 27756   662624.1597  46.608896  24.803748
# 27757   662881.2041  46.611453  24.804841
# 27758   663032.5274  46.612958  24.805485
# 42899   663540.7913  46.617879  24.797218
# 53332   663439.8193  46.616947  24.802363
# 196847  663320.7574  46.615691  24.796321
# 196852  662551.6030  46.608097  24.797414
# 196860  662757.2069  46.610220  24.804314

# %% [markdown]
# ## Create Network Graphs

# %% [markdown]
# > Based on the centroid points of the focus areas I'm going to create separate queries
#
# |id|northing | easting | zone | longitude | latitude |
# |---|--- | --- | --- | --- | --- |
# |**226**|2743775.983|662986.338|38|46.612431880531716|24.800103933690128|
# |**289**|2730367.172|664355.389|38|46.62439786793033|24.678905888873413|
# |**296**|2727519.349|671599.719|38|46.69562510125785|24.65240566666726|
# |**313**|2745300.551|672121.142|38|46.70296043739797|24.81286571847956|

# %%
def create_graph(loc, dist, transport_mode, loc_type="address"):
    # Transport mode = ‘walk’, ‘bike’, ‘drive’, ‘drive_service’, ‘all’, ‘all_private’, ‘none’
    if loc_type == "address":
        G = ox.graph_from_address(loc, distance=dist, network_type=transport_mode)
    elif loc_type == "points":
        G = ox.graph_from_point(loc, distance=dist, network_type=transport_mode )
    return G

# %%
area225 = create_graph((24.800103933690128,46.612431880531716), 7000, "walk", loc_type="points")

# %%
fig, ax = ox.plot_graph(area1, save=True);
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Create Isochrones from Network Graphs

# %%
import pandas as pd

# %%
#reading the points of the entrances 
entrances = pd.read_csv("cl_data/entrance_coords.csv")
entrances.head(2)
# Out:
#     id_0  campus_id     northing      easting  longitude   latitude
# 0   8144        290  2727254.212  672179.8513  46.701323  24.649947
# 1  12032        314  2745718.425  673273.6374  46.714411  24.816508

# %%
entrances.groupby("campus_id")
entrances.columns
# Out:
# Index(['id_0', 'campus_id', 'northing', 'easting', 'longitude', 'latitude'], dtype='object')

# %%
entrance = (entrances.loc[0,"latitude"], entrances.loc[0,"longitude"])
entrance
# Out:
# (24.64994736, 46.70132312)

# %%
# Create nodes geodataframe from Graph network (G)
gdf_nodes = ox.graph_to_gdfs(area1, edges=False)

# Specify where you want to start and get nearest nodes. 
node_start = ox.get_nearest_node(area1, point=entrance)

# Project a graph from lat-long to the UTM zone appropriate for its geographic location.
G = ox.project_graph(area1)

# %%
# Trip time in Mintues
trip_times = [5, 10, 15, 20, 25]

# walking speed in km/hour
travel_speed = 4

# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60 #km per hour to m per minute
for u, v, k, data in G.edges(data=True, keys=True):
    data['time'] = data['length'] / meters_per_minute

# %%
# get one color for each isochrone
iso_colors = ox.get_colors(n=len(trip_times), cmap='Reds', start=0.3, return_hex=True)

# color the nodes according to isochrone then plot the street network
node_colors = {}
for trip_time, color in zip(sorted(trip_times, reverse=True), iso_colors):
    subgraph = nx.ego_graph(G, node_start, radius=trip_time, distance='time') # this is really what's calculating the isochrone !!
    for node in subgraph.nodes():
        node_colors[node] = color

nc = [node_colors[node] if node in node_colors else 'none' for node in G.nodes()]
ns = [10 if node in node_colors else 0 for node in G.nodes()]
fig, ax = ox.plot_graph(G, fig_height=8, node_color=nc, node_size=ns, save=True, node_alpha=0.8, node_zorder=2)
