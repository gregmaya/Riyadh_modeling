# %%
import geopandas as gpd
import pandas as pd
from pyproj import CRS
from shapely.geometry import Point, MultiPoint, LineString, MultiLineString, Polygon, MultiPolygon
from shapely.wkb import dumps, loads #this is used to flatten geoms
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#modules needed for connecting to PostGIS
from sqlalchemy.engine.url import URL
from sqlalchemy import create_engine #needs to have psycopg2 in the environment but no need to import it
from geoalchemy2 import WKTElement, Geometry #to modify Shapely geometries into WKT before uploading to DB

# %% [markdown]
# ## Polygons reconstruction
# Reconstruct from the lines around.
#
# > use the following file in DB : **lines_for_poly**

# %%
from shapely.ops import polygonize, polygonize_full

# %% [markdown]
# ### creating engine to PostGIS

# %%
# DB parameters
HOST = 'localhost'
DB = 'sdb_course'
USER = 'postgres'
PORT = 5433
PWD = 'Dedalo1.'

# Database info
db_url = URL(drivername='postgresql+psycopg2', 
             host=HOST, 
             database=DB,
             username=USER,
             port=PORT,
             password=PWD)

# Create engine
engine = create_engine(db_url)
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5433/sdb_course)

# %%
#importing the Network sevgments
sqlquery = "SELECT * FROM riyadh.lines_for_poly;"

#note: no CRS given because the data is already projcted in the correct CRS (20438)
net_polys = gpd.read_postgis(sqlquery, engine, geom_col='geom', crs=None)

#creating a spatial index
net_polys.sindex
net_polys.head(2)
# Out:
#    id                                               geom  id_0  id_parent
# 0   1  LINESTRING (677211.890 2732125.950, 677279.804...     1          1
# 1   2  LINESTRING (667716.660 2737252.031, 668009.000...     2          2

# %%
net_polys_union = net_polys.unary_union

# %%
macro_CxHull = net_polys_union.convex_hull

# %%
type(macro_CxHull)
# Out:
# shapely.geometry.polygon.Polygon

# %%
decomposition = polygonize_full(net_polys_union)

# %%
len(decomposition[1])
# Out:
# 1009

# %%
poly_lst = []

for tpl in decomposition:
    for pol in tpl:
        poly_lst.append(pol)

len(poly_lst)
# Out:
# 43741

# %%
polygons_only = []
non_polygons = []

for p in poly_lst:
    if type(p) == Polygon :
        polygons_only.append(p)
    else:
        non_polygons.append(p)

# %%
lines_random = []
points_random = []
for l in non_polygons:
    if type(l) == LineString:
        lines_random.append(l)
    else:
        points_random.append(l)

# %%
len(lines_random)+len(polygons_only) == len(poly_lst)
# Out:
# True

# %%
polysdict = {}
polysdict["geometry"]= polygons_only
newPolys = gpd.GeoDataFrame(polysdict, crs=20438)
newPolys.head()
# Out:
#                                             geometry
# 0  POLYGON ((677211.890 2732125.950, 677279.804 2...
# 1  POLYGON ((677279.804 2732150.289, 677211.890 2...
# 2  POLYGON ((668888.583 2735568.938, 668563.242 2...
# 3  POLYGON ((668563.242 2735412.081, 668888.583 2...
# 4  POLYGON ((673497.867 2732113.537, 673509.839 2...

# %%
newPolys.plot(figsize=(8,8))

# %% [markdown]
# ## Load the raw polygons

# %%
#importing the Network sevgments
sqlquery = "SELECT * FROM riyadh.campuses_new;"

#note: no CRS given because the data is already projcted in the correct CRS (20438)
camp_2 = gpd.read_postgis(sqlquery, engine, geom_col='geom', crs=None)

#creating a spatial index
camp_2.sindex
camp_2.head(2)
# Out:
#    id                                               geom category  \
# 0   1  MULTIPOLYGON (((679977.382 2734669.908, 680392...        E
# 1   2  MULTIPOLYGON (((674069.638 2747370.597, 672094...        E
#
#       cat_name name_alias
# 0  Educational       None
# 1  Educational       None

# %%
#correcting the multipolygons to poligons
#calculating the lenght of the polygons
camp_2["num_pols"] = camp_2.geom.apply(lambda x: len(x))
camp_2.num_pols.unique()
# Out:
# array([1])

# %%
#extracting all the first iten in the series of the multipolygon
camp_2["geometry"] = camp_2.geom.apply(lambda x: x[0])
#activate the new geometry as the active one
camp_2.set_geometry("geometry",inplace=True)
#drop the old multipolygon
camp_2.drop(columns =["geom", "num_pols"], inplace=True)

# %%
#bounds of one of the areas 
bbox = (662863.4908694762, 2728254.491706719, 665918.6425654521, 2732369.2887877855)
ofsett = 500

# %%
#plot the results
ax = newPolys.plot(alpha = 0.4, color="grey", figsize=(8,8))
camp_2.plot(ax=ax, linewidth= 0) 
net_polys.plot(ax=ax, linewidth= 1.5, color="black")
ax.set_xlim(bbox[0]-ofsett,bbox[2]+ofsett)
ax.set_ylim(bbox[1]-ofsett,bbox[3]+ofsett)
ax.axis("off")
plt.tight_layout();

# %%
camp_2.head()
# Out:
#    id category     cat_name name_alias  \
# 0   1        E  Educational       None
# 1   2        E  Educational       None
# 2   3        E  Educational       None
# 3   4        E  Educational       None
# 4   5        E  Educational       None
#
#                                             geometry
# 0  POLYGON ((679977.382 2734669.908, 680392.449 2...
# 1  POLYGON ((674069.638 2747370.597, 672094.200 2...
# 2  POLYGON ((664123.232 2737549.815, 664222.626 2...
# 3  POLYGON ((671709.835 2736413.227, 671564.859 2...
# 4  POLYGON ((671938.074 2736489.916, 672387.415 2...

# %%
#join the id of the camp_2 to the new polys and discard the ones that are not joining
newPolys_join= gpd.sjoin(newPolys, camp_2, how="inner", #note that this will only keep those that do hava a match
                         op="intersects", rsuffix = "campus")
print("Number of NEW polygons:", len(newPolys))
print("Number of JOINED polygons:", len(newPolys_join))
# Out:
# number of NEW polygons: 33515
# number of JOINED polygons: 8808

# %%
#plot the results
ax = newPolys_join.plot(alpha = 0.4, color="grey", figsize=(8,8))
camp_2.plot(ax=ax, linewidth= 0) 
net_polys.plot(ax=ax, linewidth= 1.5, color="black")
ax.set_xlim(bbox[0]-ofsett,bbox[2]+ofsett)
ax.set_ylim(bbox[1]-ofsett,bbox[3]+ofsett)
ax.axis("off")
plt.tight_layout();

# %% [markdown]
# > Given that I see many more polygons selected because of old polygons going beyond lines, I will create a inner buffer and **RIGHT** join to select the ones that should be removed from the the **newPolys_join**

# %%
newPolys_join.tail()
# Out:
#                                                 geometry  index_campus   id  \
# 30799  POLYGON ((686314.234 2732140.323, 686403.403 2...           110  111
# 31862  POLYGON ((686405.082 2731967.767, 686381.553 2...           110  111
# 30806  POLYGON ((686227.251 2731478.700, 686177.228 2...           151  152
# 31557  POLYGON ((680625.290 2733597.303, 680669.410 2...            15   16
# 32812  POLYGON ((667453.452 2733090.182, 667394.252 2...           133  134
#
#       category                     cat_name name_alias  \
# 30799      MED                      Medical       None
# 31862      MED                      Medical       None
# 30806        R  Residential Gated Community       None
# 31557        E                  Educational       None
# 32812        O                      Offices       None
#
#                                                buffer-10
# 30799  POLYGON ((686328.003 2732135.636, 686407.571 2...
# 31862  POLYGON ((686413.930 2731972.426, 686395.224 2...
# 30806  POLYGON ((686222.544 2731487.523, 686181.391 2...
# 31557  POLYGON ((680639.215 2733594.859, 680675.155 2...
# 32812  POLYGON ((667462.485 2733094.471, 667407.527 2...

# %%
newPolys_join["buffer-10"] = newPolys_join.geometry.apply(lambda x : x.buffer(-10))

# %%
newPolys_subbuf = newPolys_join.drop(["geometry","index_campus","id","category","cat_name","name_alias"],axis=1)

# %%
newPolys_subbuf.set_geometry("buffer-10",inplace= True)

# %%
newPolys_subbuf_join = gpd.sjoin(newPolys_subbuf, camp_2, 
                                how="left", # by knowing which ones didn't join I'll know that those are the ones to remove
                                op="intersects", rsuffix = "campus")
len(newPolys_subbuf_join)
# Out:
# 17974

# %%
nonjoined = newPolys_subbuf_join.index_campus.isnull()
newPolys_subbuf_join[nonjoined].index
# Out:
# 7910

# %%
rmv = newPolys_subbuf_join[nonjoined].index
test = newPolys_join.drop(labels= rmv)

# %%
#plot the results
ax = test.plot(alpha = 0.4, color="grey", figsize=(8,8))
camp_2.plot(ax=ax, linewidth= 0) 
net_polys.plot(ax=ax, linewidth= 1.5, color="black")
ax.set_xlim(bbox[0]-ofsett,bbox[2]+ofsett)
ax.set_ylim(bbox[1]-ofsett,bbox[3]+ofsett)
ax.axis("off")
plt.tight_layout();

# %%
test.groupby("index_campus")

# %%
test_dissolved = test.dissolve(by="index_campus")

# %%
len(test_dissolved)
# Out:
# 319

# %%
len(camp_2)
# Out:
# 320

# %% [markdown]
# ## Saving into PostGIS

# %%
#Write to POSTGIS.
#renaming of geom column just for uploading
test_dissolved.rename(columns={"geometry": "geom_shapely"}, inplace=True)
# Convert Shapely geometries to WKTElements into column 'geom' (default in PostGIS)
net_Smpl_campus['geom'] = net_Smpl_campus['geom_shapely'].apply(lambda row: WKTElement(row.wkt, srid=20438))

# Drop Shapely geometries
net_Smpl_campus = net_Smpl_campus.drop('geom_shapely', axis=1)

# Write to PostGIS (overwrite if table exists, be careful with this!)
# Possible behavior: 'replace', 'append', 'fail'
desiredname = "net_Smpl_campu"
net_Smpl_campus.to_sql(desiredname, 
            engine, schema = "riyadh",
            if_exists='replace', index=True,
            dtype={'geom': Geometry(geometry_type='LineString', srid= 20438)})
print("%s is in the database now!" % desiredname)
